# %%
# !pipenv install xlrd openpyxl
# Out:
# Installing xlrd...
# Adding xlrd to Pipfile's [packages]...
# ✔ Installation Succeeded
# Installing openpyxl...
# Adding openpyxl to Pipfile's [packages]...
# ✔ Installation Succeeded
# Pipfile.lock (0147e5) out of date, updating to (364f13)...
# Locking [dev-packages] dependencies...
# Locking [packages] dependencies...
# Building requirements...
# Resolving dependencies...
# ✔ Success!
# ...
# Ignoring error when setting locale: unsupported locale setting
# Updated Pipfile.lock (364f13)!
# Installing dependencies from Pipfile.lock (364f13)...
#   🐍   ▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉▉ 0/0 — 00:00:00

# %%
import pandas as pd
import xlrd
import openpyxl

# %%
# !pwd
# Out:
# /home/wincuser/study/datascience

# %%
df = pd.read_excel('./Excel操作/1-2_suitou.xlsx')
df.head(20)
# Out:
#     Unnamed: 0  Unnamed: 1                                          殺菌剤① (水稲)  \
# 0          NaN         NaN                                                NaN
# 1          NaN         NaN                                        病害虫及び\n防除時期
# 2          NaN         NaN                                                NaN
# 3          NaN         NaN                                                NaN
# 4          NaN         NaN                                                NaN
# 5          NaN         NaN                            【育苗】\nばか苗病\n苗立枯細菌病\n褐条病
# 6          NaN         NaN                                                NaN
# 7          NaN         NaN                                                NaN
# 8          NaN         NaN                                                NaN
# 9          NaN         NaN                                      苗立枯病\n(リゾープス)
# 10         NaN         NaN                                                NaN
# ...
